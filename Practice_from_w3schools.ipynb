# %% [markdown]
# <a href="https://colab.research.google.com/github/Arhin-Eben/Machine-learning-with-python/blob/master/Practice_from_w3schools.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PRACTICALS FROM W3SCHOOLS**

# %%
import numpy as np
from scipy import stats
#Calculating mean
speed = [99,86,87,88,111,86,103,87,94,78,77,85,86]
x = np.mean(speed)
print(x)
# Out:
# 89.76923076923077

# %%
#Calculating the Median
y =np.median(speed)
print(y)
# Out:
# 87.0

# %%
#Calculating the mode
z = stats.mode(speed)
print(z)
# Out:
# ModeResult(mode=np.int64(86), count=np.int64(3))

# %%
#Calculating the standard deviation
import numpy as np
speed = [86,87,88,86,87,85,86]
x = np.std(speed)
print(x)
# Out:
# 0.9035079029052513

# %%
#Calculating the variance
y = np.var(speed)
print(y)
# Out:
# 0.8163265306122449

# %%
#Finding percentile (what is 75 percentile?)
ages = [5,31,43,48,50,41,7,11,15,39,80,82,32,2,8,6,25,36,27,61,31]
x = np.percentile(ages,75)
print(x)
# Out:
# 43.0

# %%
#What is the age that 90% of the people are younger than?
y = np.percentile(ages,90)
print(y)
# Out:
# 61.0

# %%
#Create an array containing 250 random floats between 0 and 5
from numpy import random
x = random.uniform(0.0,5.0,250)
print(x)
# Out:
# [1.59339218 0.30428542 3.46237037 2.21902595 0.61513093 1.31587324
#  1.19299723 2.27697391 3.85952508 1.21412155 0.8510536  4.79717113
#  1.37918416 0.96980286 4.84129447 4.30929302 2.01166106 4.9799376
#  4.45131403 1.66811125 1.30705497 3.33612726 3.31881994 3.63703238
#  4.70761314 4.18380102 3.64371029 0.3425782  1.2459086  2.2627624
#  4.82497175 0.07544476 3.81410904 2.43555725 2.63951578 2.49569077
#  2.11905263 2.42059497 1.94055258 2.68441949 3.57748848 4.63572598
#  2.0278601  3.11390168 1.73844858 4.27501891 3.79348656 3.65883595
#  4.29048151 0.09586419 0.46955458 2.70343829 2.14307956 2.12734749
#  4.43996532 0.11412593 0.06286218 2.55631395 1.56804341 0.85244399
#  1.04812768 3.44068671 2.15634744 3.27393873 2.44708007 3.68235124
#  1.88599082 1.98249859 2.24307912 3.71493459 2.03878422 3.16164044
#  2.45869686 4.7645466  1.29099381 2.02273319 0.95749807 2.75706848
#  2.1778823  3.23299482 2.28576328 1.08478436 1.39661836 0.43306928
# ...

# %%
#Draw a histogram with the data
from matplotlib import pyplot as plt
plt.hist(x,5)
plt.show()

# %%
#Create an array with 100000 random numbers, and display them using a histogram with 100 bars
x = random.uniform(0.0, 5.0, size=(100000))
plt.hist(x,100)
plt.show()

# %%
#A typical normal data distribution
x = np.random.normal(5.0, 1.0, 100000)
plt.hist(x,100)
plt.show()

# %% [markdown]
# **SCATTER PLOTS**

# %%
import matplotlib.pyplot as plt
#The x-axis represents ages, and the y-axis represents speeds
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]
plt.scatter(x,y)
plt.show()

# %%
#Array will be having the mean set to 5.0 with a standard deviation of 1.0
#Array will be having the mean set to 10.0 with a standard deviation of 2.0
x = np.random.normal(5.0, 1.0, 1000)
y = np.random.normal(10.0, 2.0, 1000)
plt.scatter(x,y)
plt.show()

# %% [markdown]
# **LINEAR REGRESSION**

# %%
#Drawing a scatter plot
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

plt.scatter(x,y)
plt.show()

# %%
#Drawing the line of Linear Regression
import matplotlib.pyplot as plt
from scipy import stats

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x,y)

def myfunc(x):
  return slope * x + intercept

  mymodel = list(map(myfunc,x))

  plt.scatter(x,y)
  plt.plot(x,mymodel)
  plt.show()

# %%
#Predict the speed of a 10 years old car
from scipy import stats

#x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
#y = [99,86,87,88,111,86,103,87,94,78,77,85,86]
x = [89,43,36,36,95,10,66,34,38,20,26,29,48,64,6,5,36,66,72,40]
y = [21,46,3,35,67,95,53,72,58,10,26,34,90,33,38,20,56,2,47,15]
slope, intercept, r, p, std_err = stats.linregress(x,y)

def myfunc(x):
  return slope * x + intercept

speed = myfunc(10)

print(speed)
# Out:
# 40.59144864292098

# %%
mymodel = list(map(myfunc,x))
plt.scatter(x,y)
plt.plot(x, mymodel)
plt.show()

# %%
#Printind 'r', r stands for relationship
x = [89,43,36,36,95,10,66,34,38,20,26,29,48,64,6,5,36,66,72,40]
y = [21,46,3,35,67,95,53,72,58,10,26,34,90,33,38,20,56,2,47,15]

slope, intercept, r, p, std_err = stats.linregress(x,y)

print(r)
# Out:
# 0.01331814154297491

# %% [markdown]
# **POLYNOMIAL REGRESSION**

# %%
x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

plt.scatter(x, y)
plt.show()

# %%
#Drawing the line of Polynomial Regression
mymodel = np.poly1d(np.polyfit(x,y,3))

myline = np.linspace(1,22,100)

plt.scatter(x,y)
plt.plot(myline,mymodel(myline))
plt.show()

# %%
#R-Squared(r2)
import numpy as np
from sklearn.metrics import r2_score

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = np.poly1d(np.polyfit(x,y,3))

print(r2_score(y,mymodel(x)))
# Out:
# 0.9432150416451026

# %%
#Predict Future Values
mymodel = np.poly1d(np.polyfit(x,y,3))

speed = mymodel(17)

print(speed)
plt.scatter(x,y)
plt.plot(myline,mymodel(myline))
plt.show()
# Out:
# 88.87331269698001

# %% [markdown]
# **MULTIPLE REGRESSION**

# %%
#Multiple Regression
import pandas as pd
from sklearn import linear_model

#loading dataset
df = pd.read_csv('data.csv')

#Making a list of independent values X
X = df[['Weight','Volume']]
#put dependent values in variable y
y = df['CO2']

#Creating LinearRegression object
regr = linear_model.LinearRegression()
regr.fit(X,y)

#predict the CO2 emission of a car where the weight is 2300kg, and the volume is 1300cm3
predictedCO2 = regr.predict([[2300,1300]])

print(predictedCO2)
# Out:
# [107.2087328]
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#Coefficient
#printing the coefficient values of the regression object
print(regr.coef_)
# Out:
# [0.00755095 0.00780526]

# %% [markdown]
# **SCALE**

# %%
#Scale features
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()

df = pd.read_csv('data.csv')

X = df[['Weight','Volume']]

scaledX = scale.fit_transform(X)

print(scaledX)
# Out:
# [[-2.10389253 -1.59336644]
#  [-0.55407235 -1.07190106]
#  [-1.52166278 -1.59336644]
#  [-1.78973979 -1.85409913]
#  [-0.63784641 -0.28970299]
#  [-1.52166278 -1.59336644]
#  [-0.76769621 -0.55043568]
#  [ 0.3046118  -0.28970299]
#  [-0.7551301  -0.28970299]
#  [-0.59595938 -0.0289703 ]
#  [-1.30803892 -1.33263375]
#  [-1.26615189 -0.81116837]
#  [-0.7551301  -1.59336644]
#  [-0.16871166 -0.0289703 ]
#  [ 0.14125238 -0.0289703 ]
#  [ 0.15800719 -0.0289703 ]
#  [ 0.3046118  -0.0289703 ]
#  [-0.05142797  1.53542584]
#  [-0.72580918 -0.0289703 ]
#  [ 0.14962979  1.01396046]
#  [ 1.2219378  -0.0289703 ]
#  [ 0.5685001   1.01396046]
#  [ 0.3046118   1.27469315]
#  [ 0.51404696 -0.0289703 ]
#  [ 0.51404696  1.01396046]
#  [ 0.72348212 -0.28970299]
#  [ 0.8281997   1.01396046]
#  [ 1.81254495  1.01396046]
#  [ 0.96642691 -0.0289703 ]
#  [ 1.72877089  1.01396046]
#  [ 1.30990057  1.27469315]
#  [ 1.90050772  1.01396046]
#  [-0.23991961 -0.0289703 ]
#  [ 0.40932938 -0.0289703 ]
# ...

# %%
#Predict CO2 Values
#Predict the CO2 emission from a 1.3 liter car that weighs 2300 kilograms:
scaledX = scale.fit_transform(X)

y = df['CO2']

regr = linear_model.LinearRegression()
regr.fit(scaledX,y)
scaled = scale.transform([[2300,1.3]])

predictedCO2 = regr.predict([scaled[0]])
print(predictedCO2)
# Out:
# [97.07204485]
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
