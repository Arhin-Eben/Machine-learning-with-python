# %% [markdown]
# <a href="https://colab.research.google.com/github/Arhin-Eben/Machine-learning-with-python/blob/master/K_means_W3Schools.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **K-MEANS**

# %%
#Import the modules you need
import matplotlib.pyplot as plt

x = [4, 5, 10, 4, 3, 11, 14 , 6, 10, 12]
y = [21, 19, 24, 17, 16, 25, 24, 22, 21, 21]

## visualizing some data points:
plt.scatter(x, y)
plt.show()

# %%
#Import the modules you need
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

#Turn the data into a set of points
data = list(zip(x, y))
inertias = []

for i in range(1,11):
  kmeans = KMeans(n_clusters=i)
  kmeans.fit(data)
  inertias.append(kmeans.inertia_)

# Move the plotting outside the loop
plt.plot(range(1,11), inertias, marker='o') # Now, 'inertias' will have all 10 values.
plt.title('Elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()

# %%
#The elbow method shows that 2 is a good value for K, so we retrain and visualize the result:
kmeans = KMeans(n_clusters=2)
kmeans.fit(data)

plt.scatter(x, y, c=kmeans.labels_)
plt.show()
